# %% [markdown]
# # Reading a PDF File

# %%
from langchain_community.document_loaders import PyPDFLoader
loader=PyPDFLoader('Shivaji_Maharaj.pdf')
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'PDFium', 'creator': 'PDFium', 'creationdate': 'D:20241008114831', 'source': 'Shivaji_Maharaj.pdf', 'total_pages': 8, 'page': 0, 'page_label': '1'}, page_content='International Journal of Cultural Studies and Social Sciences \nVol-20, Issue-1, No.61, January - June: 2024 :: ISSN: 2347-4777 (UGC CARE Journal)              26 \nCHHATRAPATI  SHIVAJI  MAHARAJ  AND HIS PUBLIC  ADMINISTRATION  \n \nDR. PRAVESH KUMAR, ASSISTANT PROFESSOR , CENTRE FOR COMPARATIVE POLITICS & \nPOLITICAL THEORY, SCHOOL OF   INTERNATIONAL STUDIES, JAWAHARLAL NEHRU UNIVERSITY , \nNEW DELHI. EMAIL: praveshkumar@mail.jnu.ac.in  \nDR. RITESH GUPTA, (PHD, JAWAHARLAL NEHRU UNIVERSITY ), \nASSISTANT PROFESSOR , HISTORY DEPARTMENT , VIVEKANANDA COLLEGE , UNIVERSITY OF DELHI.  \n \n“One who was the very incarnation of Lord Siva, about whom prophecies were given out long before \nhe was born; and his advent was eagerly expected by all the great souls and saints of Maharashtra as \nthe deli
# ...

# %% [markdown]
# # How to recursively split text by characters

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_documents=text_splitter.create_documents([doc.page_content for doc in docs])
final_documents
# Out:
# [Document(metadata={}, page_content='International Journal of Cultural Studies and Social Sciences \nVol-20, Issue-1, No.61, January - June: 2024 :: ISSN: 2347-4777 (UGC CARE Journal)              26 \nCHHATRAPATI  SHIVAJI  MAHARAJ  AND HIS PUBLIC  ADMINISTRATION  \n \nDR. PRAVESH KUMAR, ASSISTANT PROFESSOR , CENTRE FOR COMPARATIVE POLITICS & \nPOLITICAL THEORY, SCHOOL OF   INTERNATIONAL STUDIES, JAWAHARLAL NEHRU UNIVERSITY , \nNEW DELHI. EMAIL: praveshkumar@mail.jnu.ac.in  \nDR. RITESH GUPTA, (PHD, JAWAHARLAL NEHRU UNIVERSITY ),'),
# ...

# %% [markdown]
# # Text Loader

# %%
from langchain_community.document_loaders import TextLoader
loader=TextLoader('speech.txt')
loader

# %%
speech =""
with open('speech.txt', 'r') as file:
    speech = file.read()
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
final_documents=text_splitter.create_documents([speech])
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Raja Shivaji" redirects here. For the 2026 film, see Raja Shivaji (film). For other uses, see Shivaji (disambiguation).
# Shivaji I
# Raja
# Shakakarta[1]
# Haindava Dharmoddharak[2]
# Kshatriya Kulavantas[3]'
# page_content='Portrait of Shivaji (c. 1680s)
# Chhatrapati of the Marathas
# Reign	6 June 1674 – 3 April 1680
# Coronation
# 6 June 1674 (first)
# 24 September 1674 (second)
# Predecessor	Position established
# Successor	Sambhaji
# Peshwa	Moropant Trimbak Pingle
# Born	19 February 1630
# Shivneri Fort, Ahmadnagar Sultanate
# Died	3 April 1680 (aged 50)
# Raigad Fort, Mahad, Maratha Empire
# Spouse
# Sai Bhonsale
# ​
# ​(m. 1640; died 1659)​
# Soyarabai ​(m. 1650)​
# Putalabai ​(m. 1653)​
# Sakvarbai ​(m. 1657)​
# Sagunabai Shirke'

# %%
type(final_documents[0])
# Out:
# langchain_core.documents.base.Document
